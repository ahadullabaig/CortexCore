# %% [markdown]
# # 🧠 SNN Model Development & Training - CS2 Workspace
#
# **Owner:** CS2 / SNN Expert
#
# **Responsibilities:**
# - Design SNN architectures
# - Implement learning algorithms (STDP, surrogate gradients)
# - Train and optimize models
# - Hyperparameter tuning
# - Performance benchmarking
#
# **Phase:** Days 2-30

# %%
# Imports
import torch
import torch.nn as nn
import snntorch as snn
from snntorch import surrogate
from snntorch import functional as SF
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
# %matplotlib inline

# %% [markdown]
# ## TODO: Day 2-3
# - [ ] Implement basic LIF neuron model
# - [ ] Create simple 2-layer SNN
# - [ ] Test on random data
# - [ ] Verify spike generation
# - [ ] Test gradient flow

# %% [markdown]
# ## TODO: Day 4-7
# - [ ] Train on CS3's dataset
# - [ ] Achieve 85% accuracy
# - [ ] Implement surrogate gradients
# - [ ] Save best model
# - [ ] Measure energy efficiency

# %% [markdown]
# ## TODO: Day 8-14
# - [ ] Implement STDP learning
# - [ ] Build hybrid SNN-ANN
# - [ ] Multi-disease detection
# - [ ] Model compression
# - [ ] Achieve 92% accuracy
